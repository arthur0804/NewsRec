# %%
# We now obtain probability distributions over topics, by which we can cluster news into groups under topics.
# This script evalute how this clustering works, i.e., how many relevant documents are in a cluster.

# %%
import pandas as pd
import json
import xml.etree.ElementTree as ET
import numpy as np

# %%
# load qrels
qrel = pd.read_csv("../../query_topics/2018BL_answer.txt", sep = " ", header = None)
qrel.columns = ["topicid", "q0", "newsid", "rel"]

# load <topicid, newsid> pair from the xml file
tree = ET.parse('../../query_topics/2018BL_topic.xml')
root = tree.getroot()
# topic to news
t2n = {}
for i in root:
    topicid = i[0].text[-3:]
    newsid = i[1].text
    t2n[topicid] = newsid
    
# load clustering results
with open("../../topic_collection.json", "r") as f:
    cluster = json.load(f)

# %%
def count_rel_cluster():
    
    '''
    Count how many relevant documents are in the cluster
    '''
    
    recall = 0
    no_zero_rel = 0
    
    for k,v in t2n.items():
        print(k)
        n_rel_16 = qrel.loc[qrel.topicid == int(k)].loc[qrel.rel==16].shape[0]
        n_rel_8 = qrel.loc[qrel.topicid == int(k)].loc[qrel.rel==8].shape[0]
        n_rel_4 = qrel.loc[qrel.topicid == int(k)].loc[qrel.rel==4].shape[0]
        print("Total number of news with rel score of 16&8&4 is: {}".format(n_rel_16+n_rel_8+n_rel_4))
        rel_news_list = list(qrel.loc[qrel.topicid == int(k)].loc[qrel.rel==16].newsid) + \
                        list(qrel.loc[qrel.topicid == int(k)].loc[qrel.rel==8].newsid) + \
                        list(qrel.loc[qrel.topicid == int(k)].loc[qrel.rel==4].newsid)
        
        for topic_no in range(0,70):
            # find the cluster where the query news is in
            if v in cluster[str(topic_no)]:
                news_in_cluster = cluster[str(topic_no)]
                rel_news_in_cluster = len(set(rel_news_list) & set(news_in_cluster))
                print("Total number of news with rel score of 16&8&4 in cluster is: {}".format(rel_news_in_cluster))
                
                # calculate recall
                if (n_rel_16+n_rel_8+n_rel_4) == 0:
                    recall_topic = 0
                else:
                    recall_topic = rel_news_in_cluster/(n_rel_16+n_rel_8+n_rel_4)
                    recall += recall_topic
                    no_zero_rel += 1
                print(recall_topic)
                
    print(recall/no_zero_rel)

# %%
count_rel_cluster()
# Out:
# 826
# Total number of news with rel score of 16&8&4 is: 13
# Total number of news with rel score of 16&8&4 in cluster is: 3
# 0.23076923076923078
# 827
# Total number of news with rel score of 16&8&4 is: 14
# Total number of news with rel score of 16&8&4 in cluster is: 0
# 0.0
# 828
# Total number of news with rel score of 16&8&4 is: 1
# Total number of news with rel score of 16&8&4 in cluster is: 1
# 1.0
# 829
# Total number of news with rel score of 16&8&4 is: 7
# Total number of news with rel score of 16&8&4 in cluster is: 7
# 1.0
# 830
# Total number of news with rel score of 16&8&4 is: 1
# Total number of news with rel score of 16&8&4 in cluster is: 0
# 0.0
# 831
# Total number of news with rel score of 16&8&4 is: 12
# Total number of news with rel score of 16&8&4 in cluster is: 4
# 0.3333333333333333
# 832
# Total number of news with rel score of 16&8&4 is: 4
# Total number of news with rel score of 16&8&4 in cluster is: 0
# 0.0
# 833
# Total number of news with rel score of 16&8&4 is: 26
# Total number of news with rel score of 16&8&4 in cluster is: 0
# 0.0
# 834
# Total number of news with rel score of 16&8&4 is: 88
# Total number of news with rel score of 16&8&4 in cluster is: 9
# 0.10227272727272728
# 835
# Total number of news with rel score of 16&8&4 is: 4
# Total number of news with rel score of 16&8&4 in cluster is: 3
# 0.75
# 836
# Total number of news with rel score of 16&8&4 is: 3
# Total number of news with rel score of 16&8&4 in cluster is: 2
# 0.6666666666666666
# 837
# Total number of news with rel score of 16&8&4 is: 15
# Total number of news with rel score of 16&8&4 in cluster is: 0
# 0.0
# 838
# Total number of news with rel score of 16&8&4 is: 0
# Total number of news with rel score of 16&8&4 in cluster is: 0
# 0
# 839
# Total number of news with rel score of 16&8&4 is: 33
# Total number of news with rel score of 16&8&4 in cluster is: 11
# 0.3333333333333333
# 840
# Total number of news with rel score of 16&8&4 is: 31
# Total number of news with rel score of 16&8&4 in cluster is: 9
# 0.2903225806451613
# 841
# Total number of news with rel score of 16&8&4 is: 1
# Total number of news with rel score of 16&8&4 in cluster is: 1
# 1.0
# 842
# Total number of news with rel score of 16&8&4 is: 60
# Total number of news with rel score of 16&8&4 in cluster is: 20
# 0.3333333333333333
# 843
# Total number of news with rel score of 16&8&4 is: 24
# Total number of news with rel score of 16&8&4 in cluster is: 15
# 0.625
# 844
# Total number of news with rel score of 16&8&4 is: 13
# Total number of news with rel score of 16&8&4 in cluster is: 1
# 0.07692307692307693
# 845
# Total number of news with rel score of 16&8&4 is: 14
# Total number of news with rel score of 16&8&4 in cluster is: 3
# 0.21428571428571427
# 846
# Total number of news with rel score of 16&8&4 is: 1
# Total number of news with rel score of 16&8&4 in cluster is: 1
# 1.0
# 847
# Total number of news with rel score of 16&8&4 is: 16
# Total number of news with rel score of 16&8&4 in cluster is: 1
# 0.0625
# 848
# Total number of news with rel score of 16&8&4 is: 61
# Total number of news with rel score of 16&8&4 in cluster is: 16
# 0.26229508196721313
# 849
# Total number of news with rel score of 16&8&4 is: 7
# Total number of news with rel score of 16&8&4 in cluster is: 1
# 0.14285714285714285
# 850
# Total number of news with rel score of 16&8&4 is: 36
# Total number of news with rel score of 16&8&4 in cluster is: 9
# 0.25
# 851
# Total number of news with rel score of 16&8&4 is: 76
# Total number of news with rel score of 16&8&4 in cluster is: 6
# 0.07894736842105263
# 852
# Total number of news with rel score of 16&8&4 is: 22
# Total number of news with rel score of 16&8&4 in cluster is: 3
# 0.13636363636363635
# 853
# Total number of news with rel score of 16&8&4 is: 19
# Total number of news with rel score of 16&8&4 in cluster is: 6
# 0.3157894736842105
# 854
# Total number of news with rel score of 16&8&4 is: 22
# Total number of news with rel score of 16&8&4 in cluster is: 17
# 0.7727272727272727
# 855
# Total number of news with rel score of 16&8&4 is: 0
# Total number of news with rel score of 16&8&4 in cluster is: 0
# 0
# 856
# Total number of news with rel score of 16&8&4 is: 56
# Total number of news with rel score of 16&8&4 in cluster is: 52
# 0.9285714285714286
# 857
# Total number of news with rel score of 16&8&4 is: 25
# Total number of news with rel score of 16&8&4 in cluster is: 3
# 0.12
# 858
# Total number of news with rel score of 16&8&4 is: 6
# Total number of news with rel score of 16&8&4 in cluster is: 4
# 0.6666666666666666
# 859
# Total number of news with rel score of 16&8&4 is: 23
# Total number of news with rel score of 16&8&4 in cluster is: 8
# 0.34782608695652173
# 860
# Total number of news with rel score of 16&8&4 is: 30
# Total number of news with rel score of 16&8&4 in cluster is: 20
# 0.6666666666666666
# 861
# Total number of news with rel score of 16&8&4 is: 16
# Total number of news with rel score of 16&8&4 in cluster is: 12
# 0.75
# 862
# Total number of news with rel score of 16&8&4 is: 1
# Total number of news with rel score of 16&8&4 in cluster is: 0
# 0.0
# 863
# Total number of news with rel score of 16&8&4 is: 12
# Total number of news with rel score of 16&8&4 in cluster is: 9
# 0.75
# 864
# Total number of news with rel score of 16&8&4 is: 4
# Total number of news with rel score of 16&8&4 in cluster is: 3
# 0.75
# 865
# Total number of news with rel score of 16&8&4 is: 4
# Total number of news with rel score of 16&8&4 in cluster is: 0
# 0.0
# 866
# Total number of news with rel score of 16&8&4 is: 61
# Total number of news with rel score of 16&8&4 in cluster is: 15
# 0.2459016393442623
# 867
# Total number of news with rel score of 16&8&4 is: 3
# Total number of news with rel score of 16&8&4 in cluster is: 0
# 0.0
# 868
# Total number of news with rel score of 16&8&4 is: 0
# Total number of news with rel score of 16&8&4 in cluster is: 0
# 0
# 869
# Total number of news with rel score of 16&8&4 is: 15
# Total number of news with rel score of 16&8&4 in cluster is: 9
# 0.6
# 870
# Total number of news with rel score of 16&8&4 is: 3
# Total number of news with rel score of 16&8&4 in cluster is: 0
# 0.0
# 871
# Total number of news with rel score of 16&8&4 is: 8
# Total number of news with rel score of 16&8&4 in cluster is: 2
# 0.25
# 872
# Total number of news with rel score of 16&8&4 is: 147
# Total number of news with rel score of 16&8&4 in cluster is: 57
# 0.3877551020408163
# 873
# Total number of news with rel score of 16&8&4 is: 4
# Total number of news with rel score of 16&8&4 in cluster is: 0
# 0.0
# 874
# Total number of news with rel score of 16&8&4 is: 35
# Total number of news with rel score of 16&8&4 in cluster is: 6
# 0.17142857142857143
# 875
# Total number of news with rel score of 16&8&4 is: 2
# Total number of news with rel score of 16&8&4 in cluster is: 0
# 0.0
# 876
# Total number of news with rel score of 16&8&4 is: 30
# Total number of news with rel score of 16&8&4 in cluster is: 13
# 0.43333333333333335
# 877
# Total number of news with rel score of 16&8&4 is: 0
# Total number of news with rel score of 16&8&4 in cluster is: 0
# 0
# 878
# Total number of news with rel score of 16&8&4 is: 8
# 879
# Total number of news with rel score of 16&8&4 is: 17
# Total number of news with rel score of 16&8&4 in cluster is: 12
# 0.7058823529411765
# 880
# Total number of news with rel score of 16&8&4 is: 0
# Total number of news with rel score of 16&8&4 in cluster is: 0
# 0
# 881
# Total number of news with rel score of 16&8&4 is: 0
# Total number of news with rel score of 16&8&4 in cluster is: 0
# 0
# 882
# Total number of news with rel score of 16&8&4 is: 126
# Total number of news with rel score of 16&8&4 in cluster is: 25
# 0.1984126984126984
# 883
# Total number of news with rel score of 16&8&4 is: 38
# Total number of news with rel score of 16&8&4 in cluster is: 25
# 0.6578947368421053
# 884
# Total number of news with rel score of 16&8&4 is: 28
# Total number of news with rel score of 16&8&4 in cluster is: 11
# 0.39285714285714285
# 885
# Total number of news with rel score of 16&8&4 is: 38
# Total number of news with rel score of 16&8&4 in cluster is: 16
# 0.42105263157894735
# 0.3664522458532726
